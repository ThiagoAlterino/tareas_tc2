# %% [markdown]
# # Tarea 7
#
# <img src="./archivos/Imagenes/logo_UTN.svg" align="right" width="150" />
#
# Autor Thiago Alterino Perazzo
#
# <style>
#   /* Fuerza el escalado general en el PDF imprimible */
#   @media print {
#     body, .jp-Notebook, div.rendered_html, p, li {
#       font-size: 11pt !important;
#       line-height: 1.2 !important;
#     }
#
#     /* Reduce las ecuaciones de LaTeX (MathJax 3+) */
#     .mjx-chtml, .MathJax, .MathJax_Display, .mjx-container {
#       font-size: 80% !important;
#     }
#
#     /* Reduce las imágenes / esquemáticos de LTspice para ganar espacio */
#     .rendered_html img {
#       max-width: 70% !important;
#       height: auto !important;
#     }
#   }
# </style>

# %% [markdown]
# ## Consigna
#
# ![Consigna_1.png](attachment:009765b4-7dca-483b-83b1-2d495447bb1f.png)
#
# ![Consigna_2.png](attachment:8f6827ff-ece3-48b0-9b50-c3db952bf02a.png)

# %% [markdown]
# ## 1) Comprobar que el esquema se corresponde con la siguiente transferencia:
#
# - $H(z) = (1 - C_1·Z^{-N}) · \frac{b_0 + b_1·Z^{-1} + b_2·Z^{-2}}{\frac{1}{a_0} - a_1·Z^{-1} - a_2·Z^{-2}}$
#
# ![Diagrama_De_Bloques.png](attachment:bf88fb63-93cb-4b1a-bbfe-b73096feed67.png)
#
# - $ A(Z) = a_0·a_1·Z^{-1}·A(Z) + a_0·a_2·Z^{-2}·A(Z) + X(Z) - C_1·Z^{-N}·X(Z) $
# - $ Y(Z) = a_0·b_0·A(Z) + a_0·b_1·Z^{-1}·A(Z) + a_0·b_2·Z^{-2}·A(Z) $
#
# $$ Y(Z) = a_0·(b_0 + b_1·Z^{-1} + b_2·Z^{-2})·A(Z) \quad (1) $$
#
# $$ X(Z) - C_1·Z^{-N}·X(Z) = A(Z) - a_0·a_1·Z^{-1}·A(Z) - a_0·a_2·Z^{-2}·A(Z) \quad \implies \quad X(Z)·(1 - C_1·Z^{-N}) = a_0·(\frac{1}{a_0} - a_1·Z^{-1} - a_2·Z^{-2})·A(Z) $$
#
# $$ A(Z) = \frac{1 - C_1·Z^{-N}}{a_0·(\frac{1}{a_0} - a_1·Z^{-1} - a_2·Z^{-2})}·X(Z) \quad (2) $$
#
# $$(2) en (1): \quad Y(Z) = (1 - C_1·Z^{-N})·\frac{a_0·(b_0 + b_1·Z^{-1} + b_2·Z^{-2})}{a_0·(\frac{1}{a_0} - a_1·Z^{-1} - a_2·Z^{-2})}·X(Z)$$
#
# $$ \boxed{H(Z) = \frac{Y(Z)}{X(Z)} = (1 - C_1·Z^{-N})·\frac{b_0 + b_1·Z^{-1} + b_2·Z^{-2}}{\frac{1}{a_0} - a_1·Z^{-1} - a_2·Z^{-2}}} $$

# %% [markdown]
# ## 2) Filtro de media móvil (moving average ó CIC: cascaded integrator comb)
#
# - Verificar la transferencia para $ a_0 = 1, \,\, a_1 = 1, \,\, b_0 = \frac{1}{N}, \,\, c_1 = 1 \,\, y  \,\, N = 3, \,\, 4 \,\, y  \,\, 5 $
#
# $$\boxed{ H_3(Z) = \frac{1}{3} · \frac{(1 - Z^{-3})}{1 - Z^{-1}} = \frac{1}{3}·(1 + Z^{-1} + Z^{-2})}$$
#
# $$\boxed{ H_4(Z) = \frac{1}{4} · \frac{(1 - Z^{-4})}{1 - Z^{-1}} = \frac{1}{4}·(1 + Z^{-1} + Z^{-2} + Z^{-3}) }$$
#
# $$\boxed{ H_5(Z) = \frac{1}{5} · \frac{(1 - Z^{-5})}{1 - Z^{-1}} = \frac{1}{5}·(1 + Z^{-1} + Z^{-2} + Z^{-3} + Z^{-4}) }$$
#
# - ¿Es un filtro IIR o FIR ? Discuta las ventajas que tendría esta implementación respecto al filtro FIR de media móvil 3.
#
# El filtro que se calcula en el punto 1) es un filtro IIR, pero al anular las componentes $a_2, \,\, b_1 \,\, y \,\, b_2$ el filtro se comporta como un filtro FIR.
#
# - ¿Podría implementar el siguiente sistema $ h(k) = (1, 1, 1, 1, 1, 1, 1) $ con esta topología ?
#
# $$ si \,\, h(k) = (1, 1, 1, 1, 1, 1, 1) \quad \implies \quad  N = 7 \quad \implies \quad H(Z) = \frac{1}{7}·\frac{1 - Z^{-7}}{1 - Z^{-1}} $$
#
# $$\boxed{ H_7(Z) = \frac{1}{7}·(1 + Z^{-1} + Z^{-2} + Z^{-3} + Z^{-4} + Z^{-5} + Z^{-6})} $$
#
# - Diagrama de polos y ceros del filtro:
#
# ![image.png](attachment:d3ec38df-8c99-4fd0-b429-8de26f913000.png)
#
# - Respuesta en modulo:
#
# ![image.png](attachment:4fcd512c-8370-48ad-9394-e802213dbe61.png)
#
# - Respuesta de fase:
#
# ![image.png](attachment:8accb954-ec12-41a5-9418-3fc99fcca69d.png)

# %% [markdown]
# ## 3) Filtro diferenciador (differentiator)
#
# - Obtener los valores de $a_i$ y $b_k$ para obtener $y(n) = \frac{x(n) - x(n-2)}{2}$
#
# $$H(Z) = \frac{Y(Z)}{X(Z)} = (1 - C_1·Z^{-N})·\frac{b_0 + b_1·Z^{-1} + b_2·Z^{-2}}{\frac{1}{a_0} - a_1·Z^{-1} - a_2·Z^{-2}}$$
#
# $$ Y(Z)·(\frac{1}{a_0} - a_1·Z^{-1} - a_2·Z^{-2}) = (1 - C_1·Z^{-N})(b_0 + b_1·Z^{-1} + b_2·Z^{-2})·X(Z) $$
#
# $$ \frac{1}{a_0} · Y(Z) - a_1·Z^{-1} · Y(Z) - a_2·Z^{-2} · Y(Z) = b_0·X(Z) + b_1·Z^{-1}·X(Z) + b_2·Z^{-2}·X(Z) - C_1·b_0·Z^{-N}·X(Z) - C_1·b_1·Z^{-1-N}·X(Z) - C_1·b_2·Z^{-2-N}·X(Z) $$
#
# $$ \frac{1}{a_0} · y(n) - a_1 · y(n-1) - a_2·y(n-2) = b_0·x(n) + b_1·x(n-1) + b_2·x(n-2) - C_1·b_0·x(n-N) - C_1·b_1·x(n-1-N) - C_1·b_2·x(n-2-N) $$
#
# para obtener: $ \quad y(n) = \frac{x(n) - x(n-2)}{2} \quad \implies \quad y(n) = \frac{1}{2}·x(n) - \frac{1}{2}·x(n-2)$
#
# $$ \boxed{ a_0 = 1 \quad ; \quad a_1 = 0 \quad ; \quad a_2 = 0 \quad ; \quad c_1 = 0 \quad ; \quad b_0 = \frac{1}{2} \quad ; \quad b_1 = 0 \quad ; \quad b_2 = -\frac{1}{2}} $$
#
# $$H(Z) =  (1)·\frac{\frac{1}{2} + -\frac{1}{2}·Z^{-2}}{1} \quad \implies \quad \boxed{H(Z) = \frac{(1 -Z^{-2})}{2}} $$
#
# - Diagrama de polos y ceros del filtro:
#
# ![image.png](attachment:5dcdad09-bb07-4c1f-af28-8335b407740b.png)
#
# - Respuesta en modulo:
#
# ![image.png](attachment:ec1ad1b8-2c1e-4a8a-9db9-bb055917fc94.png)
#
# - Respuesta de fase:
#
# ![image.png](attachment:b29ff7d7-a679-4607-8791-f26e4adc05f9.png)
#
# - Evaluar al sistema con un seno discreto en python y comprobar si la salida se aproxima a la derivada.
#
# ![image.png](attachment:e1f34a00-77bc-4e91-8258-15e84a661bcb.png)

# %% [markdown]
# ## 4) Filtro elimina continua (DC Blocker)
#
# ### Verifique la transferencia para $a_0 = 1$, $a_1 = \beta \,\,$ para $\,\, \beta = 0.9$, $b_0 = 1$ y $b_1 = -1$
#
# $$ H(Z) =  \frac{1 - 1·Z^{-1} }{1 - 0.9·Z^{-1}} $$
#
# - Diagrama de polos y ceros del filtro:
#
# ![image.png](attachment:03829917-d294-4cca-8181-c9d29b602379.png)
#
# - Respuesta en modulo:
#
# ![image.png](attachment:79aae330-596b-4184-b055-1d2c2e0eb781.png)
#
# - Respuesta de fase:
#
# ![image.png](attachment:af65f20f-2f91-45a8-8b57-d21045036994.png)
#
# ### Determine $\beta$ para que la transferencia en $\Omega = 0.1 · \pi$ sea 3 dB menor a la transferencia en $\Omega = \pi$
#
# $$ Z = e^{j\Omega} \quad \implies \quad |H(\Omega = \pi)| = \frac{1}{\sqrt{2}} |H(\Omega = 0.1·\pi)| $$
#
# $$ H(\Omega = \pi) = \frac{1 - 1·e^{j·\pi·(-1)}}{1 - \beta·e^{j·\pi·(-1)}} = \frac{1 - 1·e^{-j·\pi}}{1 - \beta·e^{-j·\pi}} = \frac{1 - 1·(-1)}{1 - \beta·(-1)} \quad \implies \quad H(\Omega = \pi) = \frac{2}{1 + \beta} $$
#
# $$ \boxed{|H(\Omega = \pi)| = \frac{2}{1 + \beta}} $$
#
# $$ H(\Omega = 0.1·\pi) = \frac{1 - 1·e^{j·0.1·\pi·(-1)} }{1 - \beta·e^{j·0.1·\pi·(-1)}} = \frac{1 - 1·(0.95 - j·0.31) }{1 - \beta·(0.95 - j·0.31)} \quad \implies \quad H(\Omega = 0.1·\pi) = \frac{0.05 - j·0.31}{(1 - \beta·0.95) - j·0.31} $$
#
# $$ |H(\Omega = 0.1·\pi)| = \frac{\sqrt{(0.05)^2+(0.31)^2}}{\sqrt{(1-0.95·\beta)^2+(0.31)^2}} = \boxed{\frac{0.314}{\sqrt{0.9025·\beta^2 - 1.9·\beta + 1.0961}}} $$
#
# $$ |H(\Omega = 0.1·\pi)| = \frac{1}{\sqrt{2}} · |H(\Omega = \pi)| \quad \implies \quad \frac{0.314}{\sqrt{0.9025·\beta^2 - 1.9·\beta + 1.0961}} = \frac{1}{\sqrt{2}} · \frac{2}{1 + \beta} $$
#
# $$ \left(\frac{0.314}{\sqrt{0.9025·\beta^2 - 1.9·\beta + 1.0961}}\right)^2 = \left(\frac{1}{\sqrt{2}} · \frac{2}{1 + \beta}\right)^2 \quad \implies \quad \frac{0.099}{0.9025·\beta^2 - 1.9·\beta + 1.0961} = \frac{1}{2} · \frac{4}{(1 + \beta)^2} $$
#
# $$ 0.099·(1 + \beta)^2 = 2·(0.9025·\beta^2 - 1.9·\beta + 1.0961) \quad \implies \quad 0.099\beta^2 + 0.198·\beta + 0.099 = 1.805·\beta^2 - 3.8·\beta + 2.192 $$
# $$ 1.706·\beta^2 - 3.998·\beta + 2.093 = 0 \quad \implies \quad \boxed{\beta_1 = 0.789 \quad y \quad \beta_2 = 1.554} $$

# %% [markdown]
# ## 5) Filtro Peine  (Comb filter)
#
# - Verifique la transferencia para $c_1 = -1$ y N = 8
#
# El biquad se anula por lo tanto $b_0 = a_0 = 1$ y el resto de los coeficientes se hacen cero. Quedando la transferencia:
#
# $$ H(Z) = 1 + Z^{-8} $$
#
# - Diagrama de polos y ceros del filtro:
#
# ![image.png](attachment:ec12c224-c2f3-44b5-99f8-9356feb09991.png)
#
# - Respuesta en modulo:
#
# ![image.png](attachment:1f28396e-2c39-44a5-99e9-a89b9867b715.png)
#
# - Respuesta de fase:
#
# ![image.png](attachment:ddf19dc4-a105-498f-ba99-9cb50402e85a.png)
#
# - Proponga una $f_{sampling}$ y halle las frecuencias donde se generan los peaks y los nulls en el espectro.
#
# se propone $f_s = 8kH_z$, entonces:
#
# $$ H(Z) = 1 + Z^{-8} \quad y \quad Z = e^{j·2·\pi·N·\frac{f}{f_s}} \quad \implies \quad  H(Z) = 1 + e^{-j·2·\pi·8·\frac{f}{8kH_z}} = 1 + e^{-j·2·\pi\frac{f}{1kH_z}} $$
#
# $$f_{null} \implies H(Z) = 0 \quad \implies \quad H(Z) = 0 \quad \implies \quad 1 + e^{-j·2·\pi\frac{f_{null}}{1kH_z}} = 0 \implies e^{-j·2·\pi·8·\frac{f_{null}}{8kH_z}} = -1 $$
#
# $$ e^{-j·2·\pi·\frac{f_{null}}{1kH_z}} = e^{-j·(2k+1)·\pi} \quad \implies \quad -j·2·\pi·\frac{f_{null}}{1kH_z} = -j·(2k+1)·\pi \quad \implies \quad \frac{2}{1kH_z}·f_ {null} = (2k+1) \quad \implies \quad \boxed{f_ {null} = (2k+1)·500H_z} $$
#
# $$ f_{peak} \implies H(Z) = 2 \quad \implies \quad e^{-j·2·\pi\frac{f_{peak}}{1kH_z}} = 1 \quad \implies \quad e^{-j·2·\pi\frac{f_{peak}}{1kH_z}} = e^{-j·2·k·\pi} \quad \implies \quad -j·2·\pi\frac{f_{peak}}{1kH_z} = -j·2·k·\pi $$
#
# $$ \frac{f_{peak}}{1kH_z} = k \quad \implies \quad \boxed{f_{peak} = k·1kH_z} $$
